# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4f10336d31d9cd7f238af90c297b605f

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform (low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform (low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Create an empty list to hold the weather data. 
city_data = []

#Print the beginning of the logging.
print("Beginning Data Retrieval")
print("------------------------")

#Create Counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# ------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather['sys']['country']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,                    
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | buraydah
# Processing Record 2 of Set 1 | huilong
# Processing Record 3 of Set 1 | pardina
# Processing Record 4 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | faanui
# Processing Record 7 of Set 1 | puerto ayora
# Processing Record 8 of Set 1 | tasiilaq
# Processing Record 9 of Set 1 | laguna
# Processing Record 10 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 1 | katsuura
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | popondetta
# Processing Record 15 of Set 1 | bambous virieux
# Processing Record 16 of Set 1 | saint-philippe
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | nanortalik
# Processing Record 20 of Set 1 | barrow
# Processing Record 21 of Set 1 | bathsheba
# Processing Record 22 of Set 1 | vasterhaninge
# Processing Record 23 of Set 1 | comodoro rivadavia
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | lebu
# Processing Record 26 of Set 1 | zhengjiatun
# Processing Record 27 of Set 1 | ahipara
# Processing Record 28 of Set 1 | kavieng
# Processing Record 29 of Set 1 | artyk
# City not found. Skipping...
# Processing Record 30 of Set 1 | hilo
# Processing Record 31 of Set 1 | nuuk
# Processing Record 32 of Set 1 | naze
# Processing Record 33 of Set 1 | tame
# Processing Record 34 of Set 1 | thompson
# Processing Record 35 of Set 1 | agua dulce
# Processing Record 36 of Set 1 | yokadouma
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | haines junction
# Processing Record 39 of Set 1 | tymovskoye
# Processing Record 40 of Set 1 | zambezi
# Processing Record 41 of Set 1 | ewa beach
# Processing Record 42 of Set 1 | winburg
# Processing Record 43 of Set 1 | adrar
# Processing Record 44 of Set 1 | atuona
# Processing Record 45 of Set 1 | tautira
# Processing Record 46 of Set 1 | mar del plata
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | phan thiet
# Processing Record 49 of Set 1 | cape town
# Processing Record 50 of Set 1 | codrington
# Processing Record 1 of Set 2 | antalaha
# Processing Record 2 of Set 2 | mataura
# Processing Record 3 of Set 2 | grand gaube
# Processing Record 4 of Set 2 | hammerfest
# Processing Record 5 of Set 2 | kapaa
# Processing Record 6 of Set 2 | tomatlan
# Processing Record 7 of Set 2 | laem sing
# Processing Record 8 of Set 2 | new norfolk
# Processing Record 9 of Set 2 | severo-kurilsk
# Processing Record 10 of Set 2 | bethel
# Processing Record 11 of Set 2 | mutsamudu
# City not found. Skipping...
# Processing Record 12 of Set 2 | tuatapere
# Processing Record 13 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 2 | atlantic city
# Processing Record 15 of Set 2 | sitka
# Processing Record 16 of Set 2 | mvuma
# Processing Record 17 of Set 2 | yellowknife
# Processing Record 18 of Set 2 | esfarayen
# Processing Record 19 of Set 2 | porto santo
# Processing Record 20 of Set 2 | lompoc
# Processing Record 21 of Set 2 | tuktoyaktuk
# Processing Record 22 of Set 2 | kodiak
# Processing Record 23 of Set 2 | pisco
# Processing Record 24 of Set 2 | bluff
# Processing Record 25 of Set 2 | koslan
# Processing Record 26 of Set 2 | geraldton
# Processing Record 27 of Set 2 | vaini
# Processing Record 28 of Set 2 | port elizabeth
# Processing Record 29 of Set 2 | upernavik
# Processing Record 30 of Set 2 | lata
# Processing Record 31 of Set 2 | kidal
# Processing Record 32 of Set 2 | airai
# Processing Record 33 of Set 2 | hokitika
# Processing Record 34 of Set 2 | ancud
# Processing Record 35 of Set 2 | vidim
# Processing Record 36 of Set 2 | talnakh
# Processing Record 37 of Set 2 | cayenne
# Processing Record 38 of Set 2 | wanning
# Processing Record 39 of Set 2 | saskylakh
# Processing Record 40 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 42 of Set 2 | abha
# Processing Record 43 of Set 2 | thunder bay
# Processing Record 44 of Set 2 | myski
# Processing Record 45 of Set 2 | pointe michel
# Processing Record 46 of Set 2 | vanavara
# Processing Record 47 of Set 2 | isangel
# Processing Record 48 of Set 2 | pevek
# Processing Record 49 of Set 2 | pinawa
# Processing Record 50 of Set 2 | delta del tigre
# Processing Record 1 of Set 3 | butaritari
# Processing Record 2 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 3 | otake
# Processing Record 4 of Set 3 | nhulunbuy
# Processing Record 5 of Set 3 | dunedin
# Processing Record 6 of Set 3 | willowmore
# Processing Record 7 of Set 3 | kruisfontein
# Processing Record 8 of Set 3 | araioses
# Processing Record 9 of Set 3 | cockburn town
# Processing Record 10 of Set 3 | lagoa
# Processing Record 11 of Set 3 | fez
# Processing Record 12 of Set 3 | avarua
# Processing Record 13 of Set 3 | ilirska bistrica
# Processing Record 14 of Set 3 | alexandria
# Processing Record 15 of Set 3 | port lincoln
# Processing Record 16 of Set 3 | perambalur
# Processing Record 17 of Set 3 | san patricio
# Processing Record 18 of Set 3 | victoria
# Processing Record 19 of Set 3 | yar-sale
# Processing Record 20 of Set 3 | rio gallegos
# Processing Record 21 of Set 3 | general roca
# Processing Record 22 of Set 3 | dori
# Processing Record 23 of Set 3 | jieshi
# Processing Record 24 of Set 3 | pangnirtung
# Processing Record 25 of Set 3 | dikson
# Processing Record 26 of Set 3 | jamestown
# Processing Record 27 of Set 3 | kudahuvadhoo
# Processing Record 28 of Set 3 | gat
# Processing Record 29 of Set 3 | korla
# Processing Record 30 of Set 3 | havoysund
# Processing Record 31 of Set 3 | torbay
# Processing Record 32 of Set 3 | east london
# Processing Record 33 of Set 3 | lorengau
# Processing Record 34 of Set 3 | ponta do sol
# Processing Record 35 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 36 of Set 3 | namibe
# Processing Record 37 of Set 3 | norman wells
# Processing Record 38 of Set 3 | khor
# Processing Record 39 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 40 of Set 3 | qaanaaq
# Processing Record 41 of Set 3 | walvis bay
# Processing Record 42 of Set 3 | vila
# Processing Record 43 of Set 3 | baykit
# Processing Record 44 of Set 3 | sokolo
# Processing Record 45 of Set 3 | qaqortoq
# Processing Record 46 of Set 3 | cabo san lucas
# Processing Record 47 of Set 3 | dicabisagan
# Processing Record 48 of Set 3 | green river
# Processing Record 49 of Set 3 | port alfred
# Processing Record 50 of Set 3 | morgan city
# Processing Record 1 of Set 4 | pacific grove
# Processing Record 2 of Set 4 | ribeira grande
# Processing Record 3 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 4 | chokurdakh
# Processing Record 5 of Set 4 | hithadhoo
# Processing Record 6 of Set 4 | praia da vitoria
# Processing Record 7 of Set 4 | xique-xique
# Processing Record 8 of Set 4 | kushiro
# Processing Record 9 of Set 4 | hobart
# Processing Record 10 of Set 4 | krasnoselkup
# Processing Record 11 of Set 4 | lander
# Processing Record 12 of Set 4 | port augusta
# Processing Record 13 of Set 4 | iwanai
# Processing Record 14 of Set 4 | klaksvik
# Processing Record 15 of Set 4 | altay
# Processing Record 16 of Set 4 | padang
# Processing Record 17 of Set 4 | teahupoo
# Processing Record 18 of Set 4 | prince rupert
# Processing Record 19 of Set 4 | souillac
# Processing Record 20 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 4 | santa maria
# Processing Record 22 of Set 4 | cidreira
# Processing Record 23 of Set 4 | alice springs
# Processing Record 24 of Set 4 | aklavik
# Processing Record 25 of Set 4 | florianopolis
# Processing Record 26 of Set 4 | georgetown
# Processing Record 27 of Set 4 | avera
# Processing Record 28 of Set 4 | turayf
# Processing Record 29 of Set 4 | rawson
# Processing Record 30 of Set 4 | quatre cocos
# Processing Record 31 of Set 4 | lima
# Processing Record 32 of Set 4 | santa cruz
# Processing Record 33 of Set 4 | brejinho
# Processing Record 34 of Set 4 | hay river
# Processing Record 35 of Set 4 | muros
# Processing Record 36 of Set 4 | solenzo
# Processing Record 37 of Set 4 | osorno
# Processing Record 38 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 39 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 4 | bandarbeyla
# Processing Record 41 of Set 4 | clinton
# Processing Record 42 of Set 4 | vila velha
# Processing Record 43 of Set 4 | castro
# Processing Record 44 of Set 4 | bakchar
# Processing Record 45 of Set 4 | amapa
# Processing Record 46 of Set 4 | ayan
# Processing Record 47 of Set 4 | iralaya
# Processing Record 48 of Set 4 | mahebourg
# Processing Record 49 of Set 4 | tomball
# Processing Record 50 of Set 4 | saint-michel-des-saints
# Processing Record 1 of Set 5 | farafangana
# Processing Record 2 of Set 5 | maghama
# City not found. Skipping...
# Processing Record 3 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 5 | the pas
# Processing Record 5 of Set 5 | celestun
# Processing Record 6 of Set 5 | magdagachi
# Processing Record 7 of Set 5 | cherskiy
# Processing Record 8 of Set 5 | poyarkovo
# Processing Record 9 of Set 5 | sao miguel do tapuio
# Processing Record 10 of Set 5 | mwinilunga
# Processing Record 11 of Set 5 | lahij
# Processing Record 12 of Set 5 | monte santo
# Processing Record 13 of Set 5 | kieta
# Processing Record 14 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 15 of Set 5 | barrancas
# Processing Record 16 of Set 5 | nikolskoye
# Processing Record 17 of Set 5 | clyde river
# Processing Record 18 of Set 5 | esperance
# Processing Record 19 of Set 5 | chuy
# Processing Record 20 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 5 | saint-augustin
# Processing Record 22 of Set 5 | miri
# Processing Record 23 of Set 5 | tabou
# Processing Record 24 of Set 5 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 25 of Set 5 | rongcheng
# Processing Record 26 of Set 5 | arkansas city
# Processing Record 27 of Set 5 | poum
# Processing Record 28 of Set 5 | berdigestyakh
# Processing Record 29 of Set 5 | dingle
# Processing Record 30 of Set 5 | valentin gomez farias
# Processing Record 31 of Set 5 | christchurch
# Processing Record 32 of Set 5 | yulara
# Processing Record 33 of Set 5 | namatanai
# Processing Record 34 of Set 5 | nizhniy tsasuchey
# Processing Record 35 of Set 5 | richards bay
# Processing Record 36 of Set 5 | khatanga
# Processing Record 37 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 38 of Set 5 | concepcion del oro
# Processing Record 39 of Set 5 | lardos
# Processing Record 40 of Set 5 | hasaki
# Processing Record 41 of Set 5 | kavaratti
# Processing Record 42 of Set 5 | saint-felicien
# Processing Record 43 of Set 5 | agadez
# Processing Record 44 of Set 5 | vikhorevka
# Processing Record 45 of Set 5 | sohag
# Processing Record 46 of Set 5 | banjar
# Processing Record 47 of Set 5 | tuy hoa
# Processing Record 48 of Set 5 | estanzuela
# Processing Record 49 of Set 5 | merauke
# Processing Record 50 of Set 5 | sinnamary
# Processing Record 1 of Set 6 | sunland park
# Processing Record 2 of Set 6 | spas-demensk
# Processing Record 3 of Set 6 | mayumba
# Processing Record 4 of Set 6 | dinsor
# City not found. Skipping...
# Processing Record 5 of Set 6 | palmas
# Processing Record 6 of Set 6 | casablanca
# Processing Record 7 of Set 6 | jaramana
# City not found. Skipping...
# Processing Record 8 of Set 6 | vila franca do campo
# Processing Record 9 of Set 6 | provideniya
# Processing Record 10 of Set 6 | iracoubo
# Processing Record 11 of Set 6 | wajima
# Processing Record 12 of Set 6 | newport
# Processing Record 13 of Set 6 | ambulu
# Processing Record 14 of Set 6 | saldanha
# Processing Record 15 of Set 6 | pacifica
# Processing Record 16 of Set 6 | portland
# Processing Record 17 of Set 6 | carnarvon
# Processing Record 18 of Set 6 | caravelas
# Processing Record 19 of Set 6 | jinxiang
# Processing Record 20 of Set 6 | champerico
# Processing Record 21 of Set 6 | kiama
# Processing Record 22 of Set 6 | iqaluit
# Processing Record 23 of Set 6 | tessalit
# Processing Record 24 of Set 6 | vanimo
# Processing Record 25 of Set 6 | vreed en hoop
# City not found. Skipping...
# Processing Record 26 of Set 6 | cabimas
# Processing Record 27 of Set 6 | jalu
# Processing Record 28 of Set 6 | melhus
# Processing Record 29 of Set 6 | ilulissat
# Processing Record 30 of Set 6 | isernia
# Processing Record 31 of Set 6 | teyateyaneng
# Processing Record 32 of Set 6 | kommunar
# Processing Record 33 of Set 6 | hambantota
# Processing Record 34 of Set 6 | zyryanka
# Processing Record 35 of Set 6 | talakan
# Processing Record 36 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 6 | rocha
# Processing Record 38 of Set 6 | paamiut
# Processing Record 39 of Set 6 | mamlyutka
# Processing Record 40 of Set 6 | luwingu
# Processing Record 41 of Set 6 | gao
# Processing Record 42 of Set 6 | uruzgan
# Processing Record 43 of Set 6 | eregli
# Processing Record 44 of Set 6 | ponta delgada
# Processing Record 45 of Set 6 | longyearbyen
# Processing Record 46 of Set 6 | garden city
# Processing Record 47 of Set 6 | kozhva
# Processing Record 48 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 6 | taldan
# Processing Record 50 of Set 6 | coolum beach
# Processing Record 1 of Set 7 | esna
# Processing Record 2 of Set 7 | post falls
# Processing Record 3 of Set 7 | fortuna
# Processing Record 4 of Set 7 | huauchinango
# Processing Record 5 of Set 7 | skjervoy
# Processing Record 6 of Set 7 | russell
# Processing Record 7 of Set 7 | mexico
# Processing Record 8 of Set 7 | letka
# Processing Record 9 of Set 7 | tam ky
# Processing Record 10 of Set 7 | wexford
# Processing Record 11 of Set 7 | flin flon
# Processing Record 12 of Set 7 | labuhan
# Processing Record 13 of Set 7 | mouzakion
# City not found. Skipping...
# Processing Record 14 of Set 7 | oktyabrskiy
# Processing Record 15 of Set 7 | tungkang
# City not found. Skipping...
# Processing Record 16 of Set 7 | santiago
# Processing Record 17 of Set 7 | sterling
# Processing Record 18 of Set 7 | neiafu
# Processing Record 19 of Set 7 | arman
# Processing Record 20 of Set 7 | margate
# Processing Record 21 of Set 7 | nelson bay
# Processing Record 22 of Set 7 | lundazi
# Processing Record 23 of Set 7 | otacilio costa
# Processing Record 24 of Set 7 | moree
# Processing Record 25 of Set 7 | lake havasu city
# Processing Record 26 of Set 7 | lavrentiya
# Processing Record 27 of Set 7 | pio xii
# Processing Record 28 of Set 7 | lumphat
# Processing Record 29 of Set 7 | camana
# Processing Record 30 of Set 7 | hirara
# Processing Record 31 of Set 7 | kimbe
# Processing Record 32 of Set 7 | anadyr
# Processing Record 33 of Set 7 | nueva concepcion
# Processing Record 34 of Set 7 | cacu
# Processing Record 35 of Set 7 | bredasdorp
# Processing Record 36 of Set 7 | el alto
# Processing Record 37 of Set 7 | fairbanks
# Processing Record 38 of Set 7 | paso de los toros
# Processing Record 39 of Set 7 | saint anthony
# Processing Record 40 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 41 of Set 7 | hue
# Processing Record 42 of Set 7 | great yarmouth
# Processing Record 43 of Set 7 | kahului
# Processing Record 44 of Set 7 | siuna
# Processing Record 45 of Set 7 | piacabucu
# Processing Record 46 of Set 7 | formosa
# Processing Record 47 of Set 7 | tonantins
# Processing Record 48 of Set 7 | eyl
# Processing Record 49 of Set 7 | maniitsoq
# Processing Record 50 of Set 7 | aswan
# Processing Record 1 of Set 8 | paka
# Processing Record 2 of Set 8 | kuching
# Processing Record 3 of Set 8 | tagusao
# Processing Record 4 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 5 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 6 of Set 8 | urusha
# Processing Record 7 of Set 8 | takoradi
# Processing Record 8 of Set 8 | jabinyanah
# Processing Record 9 of Set 8 | hauterive
# Processing Record 10 of Set 8 | yuancheng
# Processing Record 11 of Set 8 | maine-soroa
# Processing Record 12 of Set 8 | olafsvik
# Processing Record 13 of Set 8 | ambon
# Processing Record 14 of Set 8 | sao gabriel da cachoeira
# Processing Record 15 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 8 | aqtobe
# Processing Record 17 of Set 8 | roebourne
# Processing Record 18 of Set 8 | nioro
# Processing Record 19 of Set 8 | keuruu
# Processing Record 20 of Set 8 | luwuk
# Processing Record 21 of Set 8 | zaida
# Processing Record 22 of Set 8 | riyadh
# Processing Record 23 of Set 8 | havre-saint-pierre
# Processing Record 24 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 8 | waipawa
# Processing Record 26 of Set 8 | constitucion
# Processing Record 27 of Set 8 | ostrovnoy
# Processing Record 28 of Set 8 | kaitangata
# Processing Record 29 of Set 8 | mehamn
# Processing Record 30 of Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 31 of Set 8 | samarai
# Processing Record 32 of Set 8 | sanchazi
# Processing Record 33 of Set 8 | log
# Processing Record 34 of Set 8 | antofagasta
# Processing Record 35 of Set 8 | harnosand
# Processing Record 36 of Set 8 | yaan
# Processing Record 37 of Set 8 | meulaboh
# Processing Record 38 of Set 8 | uniontown
# Processing Record 39 of Set 8 | uk
# City not found. Skipping...
# Processing Record 40 of Set 8 | sao filipe
# Processing Record 41 of Set 8 | saint-louis
# Processing Record 42 of Set 8 | puerto quijarro
# Processing Record 43 of Set 8 | kantang
# Processing Record 44 of Set 8 | kathu
# Processing Record 45 of Set 8 | areosa
# Processing Record 46 of Set 8 | nalut
# Processing Record 47 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 8 | omsukchan
# Processing Record 49 of Set 8 | sarangani
# Processing Record 50 of Set 8 | siparia
# Processing Record 1 of Set 9 | barabinsk
# Processing Record 2 of Set 9 | duncan
# Processing Record 3 of Set 9 | hofn
# Processing Record 4 of Set 9 | san policarpo
# Processing Record 5 of Set 9 | xuddur
# Processing Record 6 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 7 of Set 9 | chabahar
# Processing Record 8 of Set 9 | sioux lookout
# Processing Record 9 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 10 of Set 9 | yumaguzino
# Processing Record 11 of Set 9 | preobrazheniye
# Processing Record 12 of Set 9 | churapcha
# Processing Record 13 of Set 9 | oktyabrskoye
# Processing Record 14 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 15 of Set 9 | sarai
# Processing Record 16 of Set 9 | kenai
# Processing Record 17 of Set 9 | aracuai
# Processing Record 18 of Set 9 | kiruna
# Processing Record 19 of Set 9 | severnoye
# Processing Record 20 of Set 9 | deniliquin
# Processing Record 21 of Set 9 | komsomolskiy
# Processing Record 22 of Set 9 | urengoy
# Processing Record 23 of Set 9 | nizwa
# Processing Record 24 of Set 9 | jardim
# Processing Record 25 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 9 | poninka
# Processing Record 27 of Set 9 | miraflores
# Processing Record 28 of Set 9 | wiarton
# Processing Record 29 of Set 9 | fatsa
# Processing Record 30 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 9 | bengkulu
# Processing Record 32 of Set 9 | cap malheureux
# Processing Record 33 of Set 9 | akyab
# Processing Record 34 of Set 9 | portales
# Processing Record 35 of Set 9 | tahe
# Processing Record 36 of Set 9 | mapastepec
# Processing Record 37 of Set 9 | hailar
# Processing Record 38 of Set 9 | talara
# Processing Record 39 of Set 9 | half moon bay
# Processing Record 40 of Set 9 | muisne
# Processing Record 41 of Set 9 | muroto
# Processing Record 42 of Set 9 | sao joao da barra
# Processing Record 43 of Set 9 | nguru
# Processing Record 44 of Set 9 | beringovskiy
# Processing Record 45 of Set 9 | nea fokaia
# Processing Record 46 of Set 9 | gizo
# Processing Record 47 of Set 9 | brekstad
# Processing Record 48 of Set 9 | makakilo city
# Processing Record 49 of Set 9 | hualmay
# Processing Record 50 of Set 9 | flinders
# Processing Record 1 of Set 10 | cozumel
# Processing Record 2 of Set 10 | la ronge
# Processing Record 3 of Set 10 | iskateley
# Processing Record 4 of Set 10 | san cristobal
# Processing Record 5 of Set 10 | chapais
# Processing Record 6 of Set 10 | san pedro
# Processing Record 7 of Set 10 | broken hill
# Processing Record 8 of Set 10 | mandera
# Processing Record 9 of Set 10 | vaitape
# Processing Record 10 of Set 10 | marienburg
# Processing Record 11 of Set 10 | muravlenko
# Processing Record 12 of Set 10 | zhicheng
# Processing Record 13 of Set 10 | pudozh
# Processing Record 14 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 15 of Set 10 | tazovskiy
# Processing Record 16 of Set 10 | egvekinot
# Processing Record 17 of Set 10 | the valley
# Processing Record 18 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 10 | porbandar
# Processing Record 20 of Set 10 | aripuana
# Processing Record 21 of Set 10 | tuensang
# Processing Record 22 of Set 10 | cookeville
# Processing Record 23 of Set 10 | guerrero negro
# Processing Record 24 of Set 10 | hamilton
# Processing Record 25 of Set 10 | dzhebariki-khaya
# Processing Record 26 of Set 10 | jiwani
# Processing Record 27 of Set 10 | tutoia
# Processing Record 28 of Set 10 | port hawkesbury
# Processing Record 29 of Set 10 | mount isa
# Processing Record 30 of Set 10 | dubbo
# Processing Record 31 of Set 10 | daru
# Processing Record 32 of Set 10 | kefamenanu
# Processing Record 33 of Set 10 | ust-kulom
# Processing Record 34 of Set 10 | moyo
# Processing Record 35 of Set 10 | faya
# Processing Record 36 of Set 10 | kutum
# Processing Record 37 of Set 10 | decatur
# Processing Record 38 of Set 10 | duluth
# Processing Record 39 of Set 10 | povenets
# Processing Record 40 of Set 10 | massaguet
# Processing Record 41 of Set 10 | bay roberts
# Processing Record 42 of Set 10 | terrace
# Processing Record 43 of Set 10 | phuket
# Processing Record 44 of Set 10 | mongo
# Processing Record 45 of Set 10 | mednogorsk
# Processing Record 46 of Set 10 | gbongan
# Processing Record 47 of Set 10 | sao jose da coroa grande
# Processing Record 48 of Set 10 | saint george
# Processing Record 49 of Set 10 | atar
# Processing Record 50 of Set 10 | beyneu
# Processing Record 1 of Set 11 | palmaner
# Processing Record 2 of Set 11 | mayuge
# Processing Record 3 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 4 of Set 11 | leon
# Processing Record 5 of Set 11 | marsaxlokk
# Processing Record 6 of Set 11 | nagapattinam
# Processing Record 7 of Set 11 | garm
# City not found. Skipping...
# Processing Record 8 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 9 of Set 11 | awjilah
# Processing Record 10 of Set 11 | garowe
# Processing Record 11 of Set 11 | palmer
# Processing Record 12 of Set 11 | shitanjing
# Processing Record 13 of Set 11 | roanoke rapids
# Processing Record 14 of Set 11 | husavik
# Processing Record 15 of Set 11 | coquimbo
# Processing Record 16 of Set 11 | hutang
# Processing Record 17 of Set 11 | banda aceh
# Processing Record 18 of Set 11 | angoche
# Processing Record 19 of Set 11 | moose factory
# Processing Record 20 of Set 11 | port blair
# Processing Record 21 of Set 11 | morros
# Processing Record 22 of Set 11 | sompeta
# Processing Record 23 of Set 11 | pundaguitan
# Processing Record 24 of Set 11 | leningradskiy
# Processing Record 25 of Set 11 | abnub
# Processing Record 26 of Set 11 | aasiaat
# Processing Record 27 of Set 11 | aukra
# Processing Record 28 of Set 11 | sredniy ikorets
# Processing Record 29 of Set 11 | ust-uda
# Processing Record 30 of Set 11 | cooma
# Processing Record 31 of Set 11 | cabra
# Processing Record 32 of Set 11 | luderitz
# Processing Record 33 of Set 11 | rawlins
# Processing Record 34 of Set 11 | kerteh
# City not found. Skipping...
# Processing Record 35 of Set 11 | bandar
# Processing Record 36 of Set 11 | sidney
# Processing Record 37 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 11 | necochea
# Processing Record 39 of Set 11 | pohrebyshche
# Processing Record 40 of Set 11 | ushtobe
# Processing Record 41 of Set 11 | tiksi
# Processing Record 42 of Set 11 | srednekolymsk
# Processing Record 43 of Set 11 | guangyuan
# Processing Record 44 of Set 11 | kahramanmaras
# Processing Record 45 of Set 11 | oussouye
# Processing Record 46 of Set 11 | kovdor
# Processing Record 47 of Set 11 | cacapava do sul
# Processing Record 48 of Set 11 | los llanos de aridane
# Processing Record 49 of Set 11 | nhamunda
# Processing Record 50 of Set 11 | ode
# Processing Record 1 of Set 12 | potgietersrus
# City not found. Skipping...
# Processing Record 2 of Set 12 | teya
# Processing Record 3 of Set 12 | tongling
# Processing Record 4 of Set 12 | khorinsk
# Processing Record 5 of Set 12 | lufilufi
# Processing Record 6 of Set 12 | karakol
# Processing Record 7 of Set 12 | wairoa
# Processing Record 8 of Set 12 | qandahar
# City not found. Skipping...
# Processing Record 9 of Set 12 | bajo baudo
# City not found. Skipping...
# Processing Record 10 of Set 12 | mackenzie
# Processing Record 11 of Set 12 | hervey bay
# Processing Record 12 of Set 12 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 13 of Set 12 | salalah
# Processing Record 14 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 15 of Set 12 | ibra
# Processing Record 16 of Set 12 | plettenberg bay
# Processing Record 17 of Set 12 | finschhafen
# Processing Record 18 of Set 12 | verkhoyansk
# Processing Record 19 of Set 12 | vardo
# Processing Record 20 of Set 12 | trelew
# Processing Record 21 of Set 12 | quchan
# Processing Record 22 of Set 12 | parrita
# Processing Record 23 of Set 12 | taoudenni
# Processing Record 24 of Set 12 | malartic
# Processing Record 25 of Set 12 | kolvereid
# Processing Record 26 of Set 12 | touros
# Processing Record 27 of Set 12 | mackay
# Processing Record 28 of Set 12 | aranos
# Processing Record 29 of Set 12 | dasoguz
# Processing Record 30 of Set 12 | luohe
# Processing Record 31 of Set 12 | grajau
# Processing Record 32 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 12 | marsa matruh
# Processing Record 34 of Set 12 | ballina
# Processing Record 35 of Set 12 | viedma
# Processing Record 36 of Set 12 | sete
# Processing Record 37 of Set 12 | balabac
# Processing Record 38 of Set 12 | cururupu
# Processing Record 39 of Set 12 | usinsk
# Processing Record 40 of Set 12 | sur
# Processing Record 41 of Set 12 | tukrah
# Processing Record 42 of Set 12 | beloha
# Processing Record 43 of Set 12 | bonthe
# Processing Record 44 of Set 12 | berlevag
# Processing Record 45 of Set 12 | moroto
# Processing Record 46 of Set 12 | ban chang
# Processing Record 47 of Set 12 | dudinka
# Processing Record 48 of Set 12 | ulladulla
# Processing Record 49 of Set 12 | poco branco
# Processing Record 50 of Set 12 | baghdad
# Processing Record 1 of Set 13 | meiganga
# Processing Record 2 of Set 13 | mecca
# Processing Record 3 of Set 13 | abay
# Processing Record 4 of Set 13 | chisinau
# Processing Record 5 of Set 13 | vesyegonsk
# Processing Record 6 of Set 13 | camacupa
# Processing Record 7 of Set 13 | yumen
# Processing Record 8 of Set 13 | qui nhon
# Processing Record 9 of Set 13 | nagato
# Processing Record 10 of Set 13 | ust-omchug
# Processing Record 11 of Set 13 | boshnyakovo
# Processing Record 12 of Set 13 | balkanabat
# Processing Record 13 of Set 13 | morondava
# Processing Record 14 of Set 13 | joensuu
# Processing Record 15 of Set 13 | saquarema
# Processing Record 16 of Set 13 | kununurra
# Processing Record 17 of Set 13 | moron
# Processing Record 18 of Set 13 | tecoanapa
# Processing Record 19 of Set 13 | serov
# Processing Record 20 of Set 13 | mandurah
# Processing Record 21 of Set 13 | winnemucca
# Processing Record 22 of Set 13 | pskov
# Processing Record 23 of Set 13 | denau
# City not found. Skipping...
# Processing Record 24 of Set 13 | puerto madryn
# Processing Record 25 of Set 13 | dargaville
# Processing Record 26 of Set 13 | tsybuliv
# Processing Record 27 of Set 13 | araouane
# Processing Record 28 of Set 13 | mandleshwar
# Processing Record 29 of Set 13 | grimari
# City not found. Skipping...
# Processing Record 30 of Set 13 | broome
# Processing Record 31 of Set 13 | petropavlivka
# Processing Record 32 of Set 13 | voi
# Processing Record 33 of Set 13 | vostok
# Processing Record 34 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 35 of Set 13 | baft
# Processing Record 36 of Set 13 | sechura
# Processing Record 37 of Set 13 | suntar
# Processing Record 38 of Set 13 | karpogory
# Processing Record 39 of Set 13 | sai buri
# Processing Record 40 of Set 13 | yeppoon
# Processing Record 41 of Set 13 | brae
# Processing Record 42 of Set 13 | digby
# Processing Record 43 of Set 13 | sultanpur
# Processing Record 44 of Set 13 | ferrol
# Processing Record 45 of Set 13 | catamarca
# Processing Record 46 of Set 13 | zhangjiakou
# Processing Record 47 of Set 13 | ewo
# Processing Record 48 of Set 13 | yambio
# Processing Record 49 of Set 13 | riesa
# Processing Record 50 of Set 13 | balimo
# City not found. Skipping...
# Processing Record 1 of Set 14 | bosaso
# Processing Record 2 of Set 14 | honiara
# Processing Record 3 of Set 14 | hami
# Processing Record 4 of Set 14 | nouadhibou
# Processing Record 5 of Set 14 | vallenar
# Processing Record 6 of Set 14 | paciran
# Processing Record 7 of Set 14 | nagyoroszi
# Processing Record 8 of Set 14 | houma
# Processing Record 9 of Set 14 | kurilsk
# Processing Record 10 of Set 14 | nikel
# Processing Record 11 of Set 14 | chiniot
# Processing Record 12 of Set 14 | san quintin
# Processing Record 13 of Set 14 | qandala
# Processing Record 14 of Set 14 | dawei
# Processing Record 15 of Set 14 | belyy yar
# Processing Record 16 of Set 14 | port-gentil
# Processing Record 17 of Set 14 | valparaiso
# Processing Record 18 of Set 14 | lodja
# Processing Record 19 of Set 14 | jumla
# Processing Record 20 of Set 14 | manga
# Processing Record 21 of Set 14 | alenquer
# Processing Record 22 of Set 14 | lamar
# Processing Record 23 of Set 14 | ranghulu
# Processing Record 24 of Set 14 | marsh harbour
# Processing Record 25 of Set 14 | batticaloa
# Processing Record 26 of Set 14 | macapa
# Processing Record 27 of Set 14 | katherine
# Processing Record 28 of Set 14 | magadan
# Processing Record 29 of Set 14 | den helder
# Processing Record 30 of Set 14 | seoul
# Processing Record 31 of Set 14 | fukue
# Processing Record 32 of Set 14 | keffi
# Processing Record 33 of Set 14 | yuanping
# Processing Record 34 of Set 14 | rafaela
# Processing Record 35 of Set 14 | lhuntshi
# City not found. Skipping...
# Processing Record 36 of Set 14 | xiongzhou
# Processing Record 37 of Set 14 | karamadai
# Processing Record 38 of Set 14 | salo
# Processing Record 39 of Set 14 | bronnoysund
# Processing Record 40 of Set 14 | matadi
# Processing Record 41 of Set 14 | seddon
# Processing Record 42 of Set 14 | atasu
# Processing Record 43 of Set 14 | lubango
# Processing Record 44 of Set 14 | arkadelphia
# Processing Record 45 of Set 14 | caucaia
# Processing Record 46 of Set 14 | la orilla
# Processing Record 47 of Set 14 | kindu
# Processing Record 48 of Set 14 | araxa
# Processing Record 49 of Set 14 | varniai
# Processing Record 50 of Set 14 | mortka
# Processing Record 1 of Set 15 | sola
# Processing Record 2 of Set 15 | bo rai
# Processing Record 3 of Set 15 | gwembe
# Processing Record 4 of Set 15 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 15 | never
# Processing Record 6 of Set 15 | tilichiki
# Processing Record 7 of Set 15 | mercedes
# Processing Record 8 of Set 15 | lujiang
# Processing Record 9 of Set 15 | yamada
# Processing Record 10 of Set 15 | marinette
# Processing Record 11 of Set 15 | methoni
# Processing Record 12 of Set 15 | rexburg
# Processing Record 13 of Set 15 | ketchenery
# City not found. Skipping...
# Processing Record 14 of Set 15 | acapulco
# Processing Record 15 of Set 15 | kachug
# Processing Record 16 of Set 15 | pachino
# Processing Record 17 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 18 of Set 15 | kristiinankaupunki
# Processing Record 19 of Set 15 | zhanatas
# City not found. Skipping...
# Processing Record 20 of Set 15 | meru
# Processing Record 21 of Set 15 | deputatskiy
# Processing Record 22 of Set 15 | alpinopolis
# Processing Record 23 of Set 15 | camacha
# Processing Record 24 of Set 15 | ormara
# Processing Record 25 of Set 15 | kayiry
# Processing Record 26 of Set 15 | sorland
# Processing Record 27 of Set 15 | springbok
# Processing Record 28 of Set 15 | mangrol
# Processing Record 29 of Set 15 | mount gambier
# Processing Record 30 of Set 15 | sandwick
# Processing Record 31 of Set 15 | puerto montt
# Processing Record 32 of Set 15 | santa luzia
# Processing Record 33 of Set 15 | rena
# Processing Record 34 of Set 15 | lazaro cardenas
# Processing Record 35 of Set 15 | isabela
# Processing Record 36 of Set 15 | zhigansk
# Processing Record 37 of Set 15 | axim
# Processing Record 38 of Set 15 | tir pol
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Buraydah      SA  26.3260   43.9750     98.60        13          75
# 1       Huilong      CN  31.8111  121.6550     64.00        91          83
# 2       Pardina      RO  45.3064   28.9569     59.00        36           0
# 3     Busselton      AU -33.6500  115.3333     61.00        83           3
# 4        Faanui      PF -16.4833 -151.7500     80.40        67           5
# 5  Puerto Ayora      EC  -0.7393  -90.3518     75.70        87          27
# 6      Tasiilaq      GL  65.6145  -37.6368     37.40        75          75
# 7        Laguna      US  38.4210 -121.4238     52.00        71          20
# 8      Katsuura      JP  35.1333  140.3000     60.01        34         100
# 9       Ushuaia      AR -54.8000  -68.3000     46.40        71          75
#
#    Wind Speed Current Description
# 0       10.36       broken clouds
# 1        8.28          light rain
# 2       17.27           clear sky
# 3        3.83           clear sky
# 4        4.83           clear sky
# 5        7.90    scattered clouds
# 6        5.75       broken clouds
# 7        6.91          few clouds
# 8        1.01     overcast clouds
# 9        6.91       moderate rain

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Buraydah      SA  26.3260   43.9750     98.60        13          75
# 1       Huilong      CN  31.8111  121.6550     64.00        91          83
# 2       Pardina      RO  45.3064   28.9569     59.00        36           0
# 3     Busselton      AU -33.6500  115.3333     61.00        83           3
# 4        Faanui      PF -16.4833 -151.7500     80.40        67           5
# 5  Puerto Ayora      EC  -0.7393  -90.3518     75.70        87          27
# 6      Tasiilaq      GL  65.6145  -37.6368     37.40        75          75
# 7        Laguna      US  38.4210 -121.4238     52.00        71          20
# 8      Katsuura      JP  35.1333  140.3000     60.01        34         100
# 9       Ushuaia      AR -54.8000  -68.3000     46.40        71          75
#
#    Wind Speed Current Description
# 0       10.36       broken clouds
# 1        8.28          light rain
# 2       17.27           clear sky
# 3        3.83           clear sky
# 4        4.83           clear sky
# 5        7.90    scattered clouds
# 6        5.75       broken clouds
# 7        6.91          few clouds
# 8        1.01     overcast clouds
# 9        6.91       moderate rain

# %%
city_data_df.to_csv('WeatherPy_Database.csv')
